# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.cluster import KMeans

pd.options.display.max_columns = 200

# %%
df = pd.read_csv(r'C:\Users\nobin\Desktop\file1\Affordable_Housing.csv')
df.fillna(0,inplace=True)
df.head(500)
# Out:
#     State  Congressional_District Active_Loans AVG_Borrower_Gross_Income  \
# 0      AK                     0.0        2,926                 72,337.58
# 1      AL                     1.0        3,543                 52,733.67
# 2      AL                     2.0        2,922                 50,266.44
# 3      AL                     3.0        3,496                 50,301.94
# 4      AL                     4.0        4,699                 48,225.72
# 5      AL                     5.0        5,689                 51,169.88
# 6      AL                     6.0        3,089                 51,401.42
# 7      AL                     7.0        1,662                 52,095.04
# 8      AL                    14.0            1                 56,784.00
# 9      AR                     1.0        8,427                 46,224.40
# 10     AR                     2.0        5,576                 50,323.15
# 11     AR                     3.0        8,524                 47,661.36
# ...

# %%
test = df[["AVG_Borrower_Gross_Income","AVG_Request_Amount", "State", "AVG_No_of_Dependent"]]

test["AVG_Borrower_Gross_Income"] = test["AVG_Borrower_Gross_Income"].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test["AVG_Request_Amount"].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

# test["AVG_No_of_Dependent"] = test["AVG_No_of_Dependent"].str.replace(",","")
# test["AVG_No_of_Dependent"] = test.loc[:, "AVG_No_of_Dependent"].astype(float)
# Out:
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# ...

# %%
import matplotlib
cmap = matplotlib.colors.Colormap('jet', N=test.State.nunique())

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].AVG_Borrower_Gross_Income, test[test.State == i].AVG_Request_Amount, cmap=cmap);
plt.title("correlation between AVG_Borrower_Gross_Income and AVG_Request_Amount")
plt.xlabel("AVG_Borrower_Gross_Income")
plt.ylabel("AVG_Request_Amount")
plt.show()

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.model_selection import train_test_split

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'AVG_No_of_Dependent',]].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7085698129366933

# %%
from sklearn.ensemble import RandomForestRegressor as RNR
rf = RNR(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.6238795924127246

# %%
sorted(zip(rf.feature_importances_, ['AVG_Request_Amount', 'AVG_No_of_Dependent', 'State', 'AVG_Loan_Amount']), reverse=True)
# Out:
# [(0.9157409160753969, 'AVG_Request_Amount'),
#  (0.08425908392460289, 'AVG_No_of_Dependent')]

# %%
test = df[["AVG_Borrower_Gross_Income","AVG_Request_Amount", "State", "AVG_Appraised_Value"]]

test["AVG_Borrower_Gross_Income"] = test["AVG_Borrower_Gross_Income"].str.replace(",","")
test["AVG_Borrower_Gross_Income"] = test.loc[:, "AVG_Borrower_Gross_Income"].astype(float)

test["AVG_Request_Amount"] = test["AVG_Request_Amount"].str.replace(",","")
test["AVG_Request_Amount"] = test.loc[:, "AVG_Request_Amount"].astype(float)

test["AVG_Appraised_Value"] = test["AVG_Appraised_Value"].str.replace(",","")
test["AVG_Appraised_Value"] = test.loc[:, "AVG_Appraised_Value"].astype(float)
# Out:
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# ...

# %%
for i in test.State.unique():
    plt.scatter(test[test.State == i].AVG_Appraised_Value, test[test.State == i].AVG_Request_Amount, cmap=cmap);
plt.title("correlation between AVG_Appraised_Value and AVG_Request_Amount")
plt.xlabel("AVG_Appraised_Value")
plt.ylabel("AVG_Request_Amount")
plt.show()

# %%
test = test.dropna()

X = test[['AVG_Borrower_Gross_Income', 'AVG_Appraised_Value',]].values
Y = test.AVG_Request_Amount.values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=0)

# %%
clf = LR()

# %%
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9888745169855557

# %%
from sklearn.ensemble import RandomForestRegressor as RNR
rf = RNR(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# C:\Users\nobin\OneDrive\Documents\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.9807205522476613

# %%
sorted(zip(rf.feature_importances_, ['AVG_Borrower_Gross_Income','AVG_Loan_Amount', 'AVG_No_of_Dependent']), reverse=True)
# Out:
# [(0.9850492659669705, 'AVG_Loan_Amount'),
#  (0.014950734033030065, 'AVG_Borrower_Gross_Income')]

# %%
df.hist(figsize = (20, 20))
plt.show()

# %%
corrmat = df.corr()
fig = plt.figure(figsize = (12, 9))

sns.heatmap(corrmat, vmax = .8, squre = True)
plt.show()
